# %%
import pandas as pd

# %%
df = pd.read_csv('./nemotron_traj.csv')
df.head()
# Out:
#          id                                             prompt  \
# 0  00066667  In Alice's Wonderland, a secret bit manipulati...
# 1  000b53cf  In Alice's Wonderland, a secret bit manipulati...
# 2  00189f6a  In Alice's Wonderland, secret encryption rules...
# 3  001b24c4  In Alice's Wonderland, numbers are secretly co...
# 4  001c63cb  In Alice's Wonderland, secret encryption rules...
#
#                                            generated         correct answer  \
# 0  We need to find the rule mapping 8-bit binary ...               10010111
# 1  We need to infer mapping of 8-bit binary strin...               01000011
# 2  We have a problem: "secret encryption rules" u...      cat imagines book
# 3  We need to deduce the numeral system used. Giv...                XXXVIII
# 4  We need to figure out decryption mapping from ...  wizard creates secret
#
#              generated answer correctness      problem type
# 0                    11011101       false  bit_manipulation
# ...
